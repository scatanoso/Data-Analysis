# %% [markdown]
# # Susan Catanoso
# ## A demonstration of overfitting with a simple polynomial fit (not a neural network!!)

# %%
# import libraries that are required
import numpy as np
import sys
import matplotlib.pyplot as plt

# Load data from file into N by 2 numpy array
filename = "abalone.data.txt"
X = np.loadtxt( filename, delimiter=',', usecols=(2,4) )

# Put first column into N by 1 array called diameter
# and second column into N by 1 array called mass_observed
diameter = X[:,0]
mass_observed = X[:,1]

# I don't want to use all the data so I use the numpy function
# called random.choice to generate 10 random indices out of a total
# of diameter.size indices. Then I create smaller sample vectors that
# are just 10 in size from the complete dataset
np.random.seed(10)
print('Total dataset has ',diameter.size,' data points')
sample_size = 10
print('Will use a random sample of only ',sample_size,' data points')
sample_indices = np.random.choice(diameter.size,sample_size)
diameter_sample = diameter[sample_indices]
mass_observed_sample = mass_observed[sample_indices]

# Set the degree of the polynomial you wish for your model
# degree_of_polynomial_to_fit = 1 is a linear model y = a x + b
# degree_of_polynomial_to_fit = 2 is a quadratic model y = a x^2 + b x + c
# degree_of_polynomial_to_fit = 3 is a cubic model y = a x^3 + b x^2 + c x + d
# etc.
degree_of_polynomial_to_fit = 1

# Fit the polynomial model using the numpy polyfit function
# It returns the coefficients of an n-th degree polynomial
# that fits your data. A very useful numpy function to know!!

# np.polyfit parameters below are x values, y values and degree of fit
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)

# I want to plot the model as a line plot so I generate a large 
# set of ordered diameter values for which I can find corresponding
# model mass predictions using the polynomial function I just fitted

# np.linspace creates evenly spaced numbers from the first input (start) to the second input (stop).  
# The third input is the number of samples to generate.
diameter_sample_for_plot = np.linspace(diameter_sample.min(),diameter_sample.max(),100)

# Use the fitted model coefficients to create the model function

# np.poly1d paramters are the coefficients for the equation derived from polyfit
model_for_mass = np.poly1d(coefficients)

# Make predictions for mass using the model function and the diameter values I generated earlier
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Generate the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit ==3:
    s='rd order'
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Total dataset has  4177  data points
# Will use a random sample of only  10  data points
# Fitted model is  1 st order
# y =
#
# 5.411 x - 1.368

# %% [markdown]
# # Week 13 - Task 1
# Using a random sample of just 10 data points, create plots with fitted polynomials having degrees 1, 2, 3 etc. up to 10

# %%
np.random.seed(10)
print('Total dataset has ',diameter.size,' data points')
sample_size = 10
print('Will use a random sample of only ',sample_size,' data points')
sample_indices = np.random.choice(diameter.size,sample_size)
diameter_sample = diameter[sample_indices]
mass_observed_sample = mass_observed[sample_indices]
diameter_sample_for_plot = np.linspace(diameter_sample.min(),diameter_sample.max(),100)     
                                                          # Generate the points to use to fill in the model and draw the line

# Create a polynomial of 1 degree
degree_of_polynomial_to_fit = 1                                                             
                                                           # Set the degree of the polynomial

coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)  
                                                          # Generate the coefficients for the polynomial equation

model_for_mass = np.poly1d(coefficients)                  # Generate the equation with the derived coefficients

mass_prediction = model_for_mass(diameter_sample_for_plot)    
                                                          # Generate the results of the polynomial equation using the point generated

# Generate the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
                                                          # Scatterplot of observed data
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')
                                                          # Line generated from polynomial equation and data points
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit ==3:
    s='rd order'
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Total dataset has  4177  data points
# Will use a random sample of only  10  data points
# Fitted model is  1 st order
# y =
#
# 5.411 x - 1.368

# %%
# Create a polynomial of 2 degrees

degree_of_polynomial_to_fit = 2
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)
model_for_mass = np.poly1d(coefficients)
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Generate the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
                                                          # Scatterplot of observed data
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')
                                                          # Line generated from polynomial equation and data points
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit ==3:
    s='rd order'
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  2 nd order
# y =
#        2
# 4.535 x + 1.648 x - 0.6226

# %%
# Create a polynomial of 3 degrees

degree_of_polynomial_to_fit = 3
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)
model_for_mass = np.poly1d(coefficients)
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Generate the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
                                                          # Scatterplot of observed data
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')
                                                          # Line generated from polynomial equation and data points
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit ==3:
    s='rd order'
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  3 rd order
# y =
#         3         2
# -344.5 x + 419.2 x - 160.5 x + 19.98

# %%
# Create a polynomial of 4 degrees

degree_of_polynomial_to_fit = 4
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)
model_for_mass = np.poly1d(coefficients)
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Generate the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
                                                          # Scatterplot of observed data
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')
                                                          # Line generated from polynomial equation and data points
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit ==3:
    s='rd order'
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  4 th order
# y =
#        4        3        2
# -3637 x + 5588 x - 3151 x + 777.3 x - 70.68

# %%
# Create a polynomial of 5 degrees

degree_of_polynomial_to_fit = 5
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)
model_for_mass = np.poly1d(coefficients)
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Generate the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
                                                          # Scatterplot of observed data
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')
                                                          # Line generated from polynomial equation and data points
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit ==3:
    s='rd order'
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  5 th order
# y =
#             5             4             3        2
# -1.715e+04 x + 3.103e+04 x - 2.208e+04 x + 7748 x - 1340 x + 91.67

# %%
# Create a polynomial of 6 degrees

degree_of_polynomial_to_fit = 6
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)
model_for_mass = np.poly1d(coefficients)
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Generate the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
                                                          # Scatterplot of observed data
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')
                                                          # Line generated from polynomial equation and data points
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit ==3:
    s='rd order'
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  6 th order
# y =
#            6            5             4             3             2
# 1.557e+05 x - 4.02e+05 x + 4.234e+05 x - 2.333e+05 x + 7.103e+04 x - 1.134e+04 x + 743.2

# %%
# Create a polynomial of 7 degrees

degree_of_polynomial_to_fit = 7
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)
model_for_mass = np.poly1d(coefficients)
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Generate the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
                                                          # Scatterplot of observed data
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')
                                                          # Line generated from polynomial equation and data points
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit ==3:
    s='rd order'
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  7 th order
# y =
#             7            6             5             4             3
# -1.103e+07 x + 3.18e+07 x - 3.901e+07 x + 2.638e+07 x - 1.062e+07 x
#               2
#  + 2.543e+06 x - 3.354e+05 x + 1.879e+04

# %%
# Create a polynomial of 8 degrees

degree_of_polynomial_to_fit = 8
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)
model_for_mass = np.poly1d(coefficients)
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Generate the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
                                                          # Scatterplot of observed data
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')
                                                          # Line generated from polynomial equation and data points
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit ==3:
    s='rd order'
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  8 th order
# y =
#             8             7             6             5             4
# -4.776e+08 x + 1.587e+09 x - 2.293e+09 x + 1.881e+09 x - 9.577e+08 x
#             3             2
#  + 3.1e+08 x - 6.228e+07 x + 7.098e+06 x - 3.514e+05

# %%
# Create a polynomial of 9 degrees

degree_of_polynomial_to_fit = 9
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)
model_for_mass = np.poly1d(coefficients)
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Generate the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
                                                          # Scatterplot of observed data
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')
                                                          # Line generated from polynomial equation and data points
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit ==3:
    s='rd order'
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  9 th order
# y =
#            9             8             7             6             5
# -6.24e+10 x + 2.335e+11 x - 3.862e+11 x + 3.707e+11 x - 2.274e+11 x
#              4             3             2
#  + 9.25e+10 x - 2.494e+10 x + 4.296e+09 x - 4.293e+08 x + 1.895e+07

# %%
# Create a polynomial of 10 degrees

degree_of_polynomial_to_fit = 10
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)
model_for_mass = np.poly1d(coefficients)
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Generate the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
                                                          # Scatterplot of observed data
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')
                                                          # Line generated from polynomial equation and data points
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit ==3:
    s='rd order'
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# C:\Users\sue\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
# Fitted model is  10 th order
# y =
#             10             9             8             7             6
# -6.043e+10 x  + 1.954e+11 x - 2.589e+11 x + 1.685e+11 x - 3.753e+10 x
#              5             4             3           2
#  - 2.25e+10 x + 2.142e+10 x - 8.121e+09 x + 1.7e+09 x - 1.929e+08 x + 9.322e+06

# %% [markdown]
# # Show what degree of polynomial 'overfits' the data (i.e. is too complex).
#
# The 5th degree model generated above is very close to the 4th degree model.  Adding the 5th degree to the polynomial isn't changing the model much. The model just starts to connect the data points that exist, but that doesn't mean it will woork well for the data as a whole.
#
# Below is the 5th degree model plotted against all of the data.  You can see that the 10 observation sample came from the middle of the data.  The 5th degree model does not look like a good fit for all of the data, and neither is the 4th or 3rd.  The second looks best visually with the full data set.  Goodness of fit tests would verify which model is best.  A larger sample size would help to generate a better model.

# %%
# Create a polynomial of 5 degrees

degree_of_polynomial_to_fit = 5
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)
model_for_mass = np.poly1d(coefficients)
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Generate the plots
plt.scatter(diameter,mass_observed, marker = 'o', s=150, alpha = 0.5,label='Observed')
                                                          # Scatterplot of ALL observed data
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')
                                                          # Line generated from polynomial equation and data points
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit ==3:
    s='rd order'
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  5 th order
# y =
#             5             4             3        2
# -1.715e+04 x + 3.103e+04 x - 2.208e+04 x + 7748 x - 1340 x + 91.67

# %% [markdown]
# # Repeat this using a random sample of 100 data points. For the 1st order polynomial (linear or straight line) you may observe "under fitting", i.e. not capturing the basic signal.

# %%
np.random.seed(10)
print('Total dataset has ',diameter.size,' data points')
sample_size = 100
print('Will use a random sample of only ',sample_size,' data points')
sample_indices = np.random.choice(diameter.size,sample_size)
diameter_sample = diameter[sample_indices]
mass_observed_sample = mass_observed[sample_indices]
diameter_sample_for_plot = np.linspace(diameter_sample.min(),diameter_sample.max(),100)     
                                                          # Generate the points to use to fill in the model and draw the line

# Create a polynomial of 1 degree
degree_of_polynomial_to_fit = 1                                                             
                                                           # Set the degree of the polynomial

coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)  
                                                          # Generate the coefficients for the polynomial equation

model_for_mass = np.poly1d(coefficients)                  # Generate the equation with the derived coefficients

mass_prediction = model_for_mass(diameter_sample_for_plot)    
                                                          # Generate the results of the polynomial equation using the point generated

# Generate the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
                                                          # Scatterplot of observed data
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')
                                                          # Line generated from polynomial equation and data points
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit ==3:
    s='rd order'
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Total dataset has  4177  data points
# Will use a random sample of only  100  data points
# Fitted model is  1 st order
# y =
#
# 4.604 x - 1.029

# %%
# Create a polynomial of 2 degrees

degree_of_polynomial_to_fit = 2
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)
model_for_mass = np.poly1d(coefficients)
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Generate the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
                                                          # Scatterplot of observed data
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')
                                                          # Line generated from polynomial equation and data points
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit ==3:
    s='rd order'
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  2 nd order
# y =
#        2
# 11.74 x - 4.171 x + 0.4672

# %%
# Create a polynomial of 3 degrees

degree_of_polynomial_to_fit = 3
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)
model_for_mass = np.poly1d(coefficients)
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Generate the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
                                                          # Scatterplot of observed data
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')
                                                          # Line generated from polynomial equation and data points
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit ==3:
    s='rd order'
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  3 rd order
# y =
#        3         2
# 20.24 x - 9.977 x + 3.072 x - 0.2648

# %%
# Create a polynomial of 4 degrees

degree_of_polynomial_to_fit = 4
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)
model_for_mass = np.poly1d(coefficients)
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Generate the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
                                                          # Scatterplot of observed data
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')
                                                          # Line generated from polynomial equation and data points
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit ==3:
    s='rd order'
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  4 th order
# y =
#        4         3         2
# 31.31 x - 23.76 x + 11.96 x - 1.465 x + 0.05709

# %%
# Create a polynomial of 5 degrees

degree_of_polynomial_to_fit = 5
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)
model_for_mass = np.poly1d(coefficients)
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Generate the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
                                                          # Scatterplot of observed data
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')
                                                          # Line generated from polynomial equation and data points
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit ==3:
    s='rd order'
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  5 th order
# y =
#         5         4         3         2
# -45.98 x + 111.3 x - 76.89 x + 28.67 x - 3.926 x + 0.1912

# %%
# Create a polynomial of 6 degrees

degree_of_polynomial_to_fit = 6
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)
model_for_mass = np.poly1d(coefficients)
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Generate the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
                                                          # Scatterplot of observed data
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')
                                                          # Line generated from polynomial equation and data points
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit ==3:
    s='rd order'
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  6 th order
# y =
#       6        5        4        3         2
# 2055 x - 4332 x + 3700 x - 1612 x + 380.2 x - 44.45 x + 2.012

# %%
# Create a polynomial of 7 degrees

degree_of_polynomial_to_fit = 7
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)
model_for_mass = np.poly1d(coefficients)
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Generate the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
                                                          # Scatterplot of observed data
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')
                                                          # Line generated from polynomial equation and data points
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit ==3:
    s='rd order'
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  7 th order
# y =
#            7             6             5            4             3
# 7.392e+04 x - 1.778e+05 x + 1.775e+05 x - 9.49e+04 x + 2.923e+04 x
#          2
#  - 5159 x + 481.5 x - 18.24

# %%
# Create a polynomial of 8 degrees

degree_of_polynomial_to_fit = 8
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)
model_for_mass = np.poly1d(coefficients)
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Generate the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
                                                          # Scatterplot of observed data
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')
                                                          # Line generated from polynomial equation and data points
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit ==3:
    s='rd order'
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  8 th order
# y =
#            8             7             6             5             4
# 7.404e+05 x - 1.974e+06 x + 2.233e+06 x - 1.397e+06 x + 5.267e+05 x
#               3             2
#  - 1.223e+05 x + 1.702e+04 x - 1296 x + 41.27

# %%
# Create a polynomial of 9 degrees

degree_of_polynomial_to_fit = 9
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)
model_for_mass = np.poly1d(coefficients)
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Generate the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
                                                          # Scatterplot of observed data
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')
                                                          # Line generated from polynomial equation and data points
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit ==3:
    s='rd order'
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  9 th order
# y =
#             9            8             7             6             5
# -9.611e+05 x + 3.74e+06 x - 6.035e+06 x + 5.357e+06 x - 2.898e+06 x
#               4             3             2
#  + 9.932e+05 x - 2.157e+05 x + 2.863e+04 x - 2105 x + 65.32

# %%
# Create a polynomial of 10 degrees

degree_of_polynomial_to_fit = 10
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)
model_for_mass = np.poly1d(coefficients)
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Generate the plots
plt.scatter(diameter_sample,mass_observed_sample, marker = 'o', s=150, alpha = 0.5,label='Observed')
                                                          # Scatterplot of observed data
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')
                                                          # Line generated from polynomial equation and data points
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit ==3:
    s='rd order'
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  10 th order
# y =
#             10             9             8             7             6
# -5.997e+07 x  + 2.073e+08 x - 3.151e+08 x + 2.766e+08 x - 1.551e+08 x
#               5             4             3             2
#  + 5.795e+07 x - 1.458e+07 x + 2.438e+06 x - 2.585e+05 x + 1.569e+04 x - 413.6

# %% [markdown]
# # Here is the 5th degree polynomial generated from a larger sample size.  This 5th degree model created with the 100 observations looks like it is a better fit to the overall data than the model generated from only 10 data points.  As to which model is the best, a goodness of fit test should be run.

# %%
# Create a polynomial of 5 degrees

degree_of_polynomial_to_fit = 5
coefficients = np.polyfit(diameter_sample, mass_observed_sample, degree_of_polynomial_to_fit)
model_for_mass = np.poly1d(coefficients)
mass_prediction = model_for_mass(diameter_sample_for_plot)

# Generate the plots
plt.scatter(diameter,mass_observed, marker = 'o', s=150, alpha = 0.5,label='Observed')
                                                          # Scatterplot of ALL observed data
plt.plot(diameter_sample_for_plot,mass_prediction,color='red',label='Model')
                                                          # Line generated from polynomial equation and data points
plt.xlabel('Diameter')
plt.ylabel('Mass')
plt.title('Mass versus diameter of abalone - observed and predicted')
plt.legend(loc='best')
plt.show()

if degree_of_polynomial_to_fit == 1:
    s='st order'
elif degree_of_polynomial_to_fit == 2:
    s='nd order'
elif degree_of_polynomial_to_fit ==3:
    s='rd order'
else:
    s='th order'
    
print('Fitted model is ',degree_of_polynomial_to_fit,s)
print('y = ')
print(model_for_mass)
# Out:
# Fitted model is  5 th order
# y =
#         5         4         3         2
# -45.98 x + 111.3 x - 76.89 x + 28.67 x - 3.926 x + 0.1912
